# %%
import os
# %pwd
# Out:
# 'f:\\ProjectAI\\My-AI-Assistant\\notebook'

# %%
os.chdir("../")
# %pwd
# Out:
# 'f:\\ProjectAI\\My-AI-Assistant'

# %%
from src.llm.ollama_client import OllamaClient

# %%
ollama = OllamaClient()
ollama.invoke("Hello")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ollama = OllamaClient()
#       2 ollama.invoke("Hello")
#
# File f:\ProjectAI\My-AI-Assistant\src\llm\ollama_client.py:7, in OllamaClient.__init__(self)
#       6 def __init__(self):
# ----> 7     super().__init__("ollama")
#
# File f:\ProjectAI\My-AI-Assistant\src\llm\base.py:27, in BaseClient.__init__(self, provider_key)
#      25 self.api_key = os.getenv(f"{provider_key.upper()}_API_KEY")
#      26 if not self.api_key:
# ---> 27     raise ValueError(f"Missing environment variable: {provider_key.upper()}_API_KEY")
#      29 # Khởi tạo client thật của LLM provider
#      30 self.client = self._create_client()
#
# ValueError: Missing environment variable: OLLAMA_API_KEY
